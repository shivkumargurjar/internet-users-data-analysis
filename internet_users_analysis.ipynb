# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls /content/drive/MyDrive | grep "Final.csv"
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_path = "/content/drive/MyDrive/Final.csv"
df = pd.read_csv(file_path)

print(df)

df_2000=df[((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2000)]
top_5_2000=df_2000.nlargest(5,'No. of Internet Users')

first_2000_val=top_5_2000.iloc[0]['No. of Internet Users']
first_2000_nam=top_5_2000.iloc[0]['Entity']

second_2000_val=top_5_2000.iloc[1]['No. of Internet Users']
second_2000_nam=top_5_2000.iloc[1]['Entity']

third_2000_val=top_5_2000.iloc[2]['No. of Internet Users']
third_2000_nam=top_5_2000.iloc[2]['Entity']

fourth_2000_val=top_5_2000.iloc[3]['No. of Internet Users']
fourth_2000_nam=top_5_2000.iloc[3]['Entity']

fifth_2000_val=top_5_2000.iloc[4]['No. of Internet Users']
fifth_2000_nam=top_5_2000.iloc[4]['Entity']

others_2000=df_2000.loc[~df_2000['Entity'].isin(top_5_2000['Entity']),'No. of Internet Users'].sum()


df_2020=df[((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2020)]
top_5_2020=df_2020.nlargest(5,'No. of Internet Users')

first_2020_val=top_5_2020.iloc[0]['No. of Internet Users']
first_2020_nam=top_5_2020.iloc[0]['Entity']

second_2020_val=top_5_2020.iloc[1]['No. of Internet Users']
second_2020_nam=top_5_2020.iloc[1]['Entity']

third_2020_nam=top_5_2020.iloc[2]['Entity']
third_2020_val=top_5_2020.iloc[2]['No. of Internet Users']

fourth_2020_nam=top_5_2020.iloc[3]['Entity']
fourth_2020_val=top_5_2020.iloc[3]['No. of Internet Users']

fifth_2020_nam=top_5_2020.iloc[4]['Entity']
fifth_2020_val=top_5_2020.iloc[4]['No. of Internet Users']

others_2020=df_2020.loc[~df_2020['Entity'].isin(top_5_2020['Entity']),'No. of Internet Users'].sum()

fig,ax=plt.subplots(1,2,figsize=(14,6))
ax[0].pie(
    [first_2000_val, second_2000_val, third_2000_val, fourth_2000_val, fifth_2000_val,others_2000],
    labels=[first_2000_nam, second_2000_nam, third_2000_nam, fourth_2000_nam, fifth_2000_nam,'Other Countries'],
    autopct='%1.1f%%')
ax[0].set_title('Top 5 Countries with Most Internet Users in 2000')

ax[1].pie(
    [first_2020_val, second_2020_val, third_2020_val, fourth_2020_val, fifth_2020_val,others_2020],
    labels=[first_2020_nam, second_2020_nam, third_2020_nam, fourth_2020_nam, fifth_2020_nam,'Other Countries'],
    autopct='%1.1f%%')
ax[1].set_title('Top 5 Countries with Most Internet Users in 2020')
plt.show()


ind_df=df[df['Entity']=='India']
plt.plot(ind_df['Year'],ind_df['Cellular Subscription'])
plt.plot(ind_df['Year'],ind_df['Internet Users(%)'])
plt.plot(ind_df['Year'],ind_df['No. of Internet Users']/10000000)
plt.plot(ind_df['Year'],ind_df['Broadband Subscription'])
plt.legend(['Cellular Subscription','Internet Users(%)','No. of Internet Users in 10 million','Broadband Subscription'])
plt.xlabel('Year')
plt.ylabel('Values')
plt.title('India',fontsize="40")
plt.show()

fig,ax=plt.subplots(1,2,figsize=(14,6))
max_2000_a = df[((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2000)].nlargest(10, 'Cellular Subscription')
ax[0].bar(max_2000_a['Entity'], max_2000_a['Cellular Subscription'], color='skyblue')
ax[0].set_xticks(range(len(max_2000_a['Entity'])))
ax[0].set_xticklabels(max_2000_a['Entity'],rotation=45)
ax[0].set_ylabel("No. of Cellular Subscription")
ax[0].set_xlabel("Entity")
ax[0].set_title("Top 10 Countries with Most Cellular Subscription in 2000")
max_2020_a = df[((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2020)].nlargest(10, 'Cellular Subscription')
ax[1].bar(max_2020_a['Entity'], max_2020_a['Cellular Subscription'], color='skyblue')
ax[1].set_xticks(range(len(max_2020_a['Entity'])))
ax[1].set_xticklabels(max_2020_a['Entity'],rotation=45)
ax[1].set_ylabel("No. of Cellular Subscription")
ax[1].set_xlabel("Entity")
ax[1].set_title("Top 10 Countries with Most Cellular Subscription in 2020")
plt.show()

fig,ax=plt.subplots(1,2,figsize=(14,6))
max_2000 = df[((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2000)].nlargest(10, 'No. of Internet Users')
ax[0].bar(max_2000['Entity'], max_2000['No. of Internet Users'], color='skyblue')
ax[0].set_xticks(range(len(max_2000['Entity'])))
ax[0].set_xticklabels(max_2000['Entity'],rotation=45)
ax[0].set_ylabel("No. of Internet Users")
ax[0].set_xlabel("Entity")
ax[0].set_title("Top 10 Countries with Most Internet Users in 2000")
max_2020 = df[((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2020)].nlargest(10, 'No. of Internet Users')
ax[1].bar(max_2020['Entity'], max_2020['No. of Internet Users'], color='skyblue')
ax[1].set_xticks(range(len(max_2020['Entity'])))
ax[1].set_xticklabels(max_2020['Entity'],rotation=45)
ax[1].set_ylabel("No. of Internet Users")
ax[1].set_xlabel("Entity")
ax[1].set_title("Top 10 Countries with Most Internet Users in 2020")
plt.show()

top_10 = df[(df['Entity'] != 'World') & (df['Entity'] != 'North America') & (df['Year'] == 2020)].nlargest(10, 'No. of Internet Users')
entities = top_10['Entity'].tolist()

plt.figure(figsize=(10, 8))
for entity in entities:
    subset = df[df['Entity'] == entity]
    plt.plot(subset['Year'], subset['No. of Internet Users'], label=entity)
plt.legend()
plt.xlabel('Year')
plt.ylabel('No. of Internet Users')
plt.title('Top 10 Countries with Most Internet Users in 2020')
plt.show()


fig,ax=plt.subplots(1,2,figsize=(14,6))
max_2000_1 = df[((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2000)].nlargest(10, 'Internet Users(%)')
ax[0].bar(max_2000_1['Entity'], max_2000_1['Internet Users(%)'], color='skyblue')
ax[0].set_xticks(range(len(max_2000_1['Entity'])))
ax[0].set_xticklabels(max_2000_1['Entity'],rotation=45)
ax[0].set_ylabel("Internet Users(%)")
ax[0].set_xlabel("Entity")
ax[0].set_title("Top 10 Countries with Most % internet users in 2000")
max_2020_1 = df[((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2020)].nlargest(10, 'Internet Users(%)')
ax[1].bar(max_2020_1['Entity'], max_2020_1['Internet Users(%)'], color='skyblue')
ax[1].set_xticks(range(len(max_2020_1['Entity'])))
ax[1].set_xticklabels(max_2020_1['Entity'],rotation=60)
ax[1].set_ylabel("Internet Users(%)")
ax[1].set_xlabel("Entity")
ax[1].set_title("Top 10 Countries with Most % internet users in 2020")
plt.show()

fig,ax=plt.subplots(1,2,figsize=(14,6))
max_2000_2 = df[((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2000)].nlargest(10, 'Broadband Subscription')
ax[0].bar(max_2000_2['Entity'], max_2000_2['Broadband Subscription'], color='skyblue')
ax[0].set_xticks(range(len(max_2000_2['Entity'])))
ax[0].set_xticklabels(max_2000_2['Entity'],rotation=45)
ax[0].set_ylabel("Broadband Subscription")
ax[0].set_xlabel("Entity")
ax[0].set_title("Top 10 Countries with Most broadband in 2000")
max_2020_2 = df[((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2020)].nlargest(10, 'Broadband Subscription')
ax[1].bar(max_2020_2['Entity'], max_2020_2['Broadband Subscription'], color='skyblue')
ax[1].set_xticks(range(len(max_2020_2['Entity'])))
ax[1].set_xticklabels(max_2020_2['Entity'],rotation=60)
ax[1].set_ylabel("Broadband Subscription")
ax[1].set_xlabel("Entity")
ax[1].set_title("Top 10 Countries with Most broadband users in 2020")
plt.show()

continent_mapping = {
    'Afghanistan': 'Asia', 'Albania': 'Europe', 'Algeria': 'Africa', 'Andorra': 'Europe', 'Angola': 'Africa',
    'Antigua and Barbuda': 'North America', 'Argentina': 'South America', 'Armenia': 'Asia', 'Australia': 'Oceania',
    'Austria': 'Europe', 'Azerbaijan': 'Asia', 'Bahamas': 'North America', 'Bahrain': 'Asia', 'Bangladesh': 'Asia',
    'Barbados': 'North America', 'Belarus': 'Europe', 'Belgium': 'Europe', 'Belize': 'North America', 'Benin': 'Africa',
    'Bhutan': 'Asia', 'Bolivia': 'South America', 'Bosnia and Herzegovina': 'Europe', 'Botswana': 'Africa',
    'Brazil': 'South America', 'Brunei': 'Asia', 'Bulgaria': 'Europe', 'Burkina Faso': 'Africa', 'Burundi': 'Africa',
    'Cabo Verde': 'Africa', 'Cambodia': 'Asia', 'Cameroon': 'Africa', 'Canada': 'North America', 'Central African Republic': 'Africa',
    'Chad': 'Africa', 'Chile': 'South America', 'China': 'Asia', 'Colombia': 'South America', 'Comoros': 'Africa',
    'Congo (Congo-Brazzaville)': 'Africa', 'Costa Rica': 'North America', 'Croatia': 'Europe', 'Cuba': 'North America',
    'Cyprus': 'Asia', 'Czechia (Czech Republic)': 'Europe', 'Denmark': 'Europe', 'Djibouti': 'Africa', 'Dominica': 'North America',
    'Dominican Republic': 'North America', 'Ecuador': 'South America', 'Egypt': 'Africa', 'El Salvador': 'North America',
    'Equatorial Guinea': 'Africa', 'Eritrea': 'Africa', 'Estonia': 'Europe', 'Eswatini (fmr. "Swaziland")': 'Africa',
    'Ethiopia': 'Africa', 'Fiji': 'Oceania', 'Finland': 'Europe', 'France': 'Europe', 'Gabon': 'Africa',
    'Gambia': 'Africa', 'Georgia': 'Asia', 'Germany': 'Europe', 'Ghana': 'Africa', 'Greece': 'Europe',
    'Grenada': 'North America', 'Guatemala': 'North America', 'Guinea': 'Africa', 'Guinea-Bissau': 'Africa',
    'Guyana': 'South America', 'Haiti': 'North America', 'Honduras': 'North America', 'Hungary': 'Europe',
    'Iceland': 'Europe', 'India': 'Asia', 'Indonesia': 'Asia', 'Iran': 'Asia', 'Iraq': 'Asia',
    'Ireland': 'Europe', 'Israel': 'Asia', 'Italy': 'Europe', 'Jamaica': 'North America', 'Japan': 'Asia',
    'Jordan': 'Asia', 'Kazakhstan': 'Asia', 'Kenya': 'Africa', 'Kiribati': 'Oceania', 'Kuwait': 'Asia',
    'Kyrgyzstan': 'Asia', 'Laos': 'Asia', 'Latvia': 'Europe', 'Lebanon': 'Asia', 'Lesotho': 'Africa',
    'Liberia': 'Africa', 'Libya': 'Africa', 'Liechtenstein': 'Europe', 'Lithuania': 'Europe', 'Luxembourg': 'Europe',
    'Madagascar': 'Africa', 'Malawi': 'Africa', 'Malaysia': 'Asia', 'Maldives': 'Asia', 'Mali': 'Africa',
    'Malta': 'Europe', 'Marshall Islands': 'Oceania', 'Mauritania': 'Africa', 'Mauritius': 'Africa',
    'Mexico': 'North America', 'Micronesia': 'Oceania', 'Moldova': 'Europe', 'Monaco': 'Europe', 'Mongolia': 'Asia',
    'Montenegro': 'Europe', 'Morocco': 'Africa', 'Mozambique': 'Africa', 'Myanmar (Burma)': 'Asia',
    'Namibia': 'Africa', 'Nauru': 'Oceania', 'Nepal': 'Asia', 'Netherlands': 'Europe', 'New Zealand': 'Oceania',
    'Nicaragua': 'North America', 'Niger': 'Africa', 'Nigeria': 'Africa', 'North Korea': 'Asia', 'North Macedonia': 'Europe',
    'Norway': 'Europe', 'Oman': 'Asia', 'Pakistan': 'Asia', 'Palau': 'Oceania', 'Palestine': 'Asia', 'Panama': 'North America',
    'Papua New Guinea': 'Oceania', 'Paraguay': 'South America', 'Peru': 'South America', 'Philippines': 'Asia',
    'Poland': 'Europe', 'Portugal': 'Europe', 'Qatar': 'Asia', 'Romania': 'Europe', 'Russia': 'Europe',
    'Rwanda': 'Africa', 'Saint Kitts and Nevis': 'North America', 'Saint Lucia': 'North America',
    'Saint Vincent and the Grenadines': 'North America', 'Samoa': 'Oceania', 'San Marino': 'Europe',
    'Saudi Arabia': 'Asia', 'Senegal': 'Africa', 'Serbia': 'Europe', 'Seychelles': 'Africa', 'Sierra Leone': 'Africa',
    'Singapore': 'Asia', 'Slovakia': 'Europe', 'Slovenia': 'Europe', 'Solomon Islands': 'Oceania', 'Somalia': 'Africa',
    'South Africa': 'Africa', 'South Korea': 'Asia', 'South Sudan': 'Africa', 'Spain': 'Europe', 'Sri Lanka': 'Asia',
    'Sudan': 'Africa', 'Suriname': 'South America', 'Sweden': 'Europe', 'Switzerland': 'Europe', 'Syria': 'Asia',
    'Tajikistan': 'Asia', 'Tanzania': 'Africa', 'Thailand': 'Asia', 'Timor-Leste': 'Asia', 'Togo': 'Africa',
    'Tonga': 'Oceania', 'Trinidad and Tobago': 'North America', 'Tunisia': 'Africa', 'Turkey': 'Asia',
    'Turkmenistan': 'Asia', 'Tuvalu': 'Oceania', 'Uganda': 'Africa', 'Ukraine': 'Europe', 'United Arab Emirates': 'Asia',
    'United Kingdom': 'Europe', 'United States': 'North America', 'Uruguay': 'South America', 'Uzbekistan': 'Asia',
    'Vanuatu': 'Oceania', 'Vatican City': 'Europe', 'Venezuela': 'South America', 'Vietnam': 'Asia',
    'Yemen': 'Asia', 'Zambia': 'Africa', 'Zimbabwe': 'Africa'
}

# Add continent column
df['Continent'] = df['Entity'].map(continent_mapping)

sum_IU_00_as=df.loc[(df['Continent']=='Asia') & (df['Year']==2000),'Internet Users(%)'].mean()
sum_IU_00_eu=df.loc[(df['Continent']=='Europe') & (df['Year']==2000),'Internet Users(%)'].mean()
sum_IU_00_na=df.loc[(df['Continent']=='North America') & (df['Year']==2000),'Internet Users(%)'].mean()
sum_IU_00_sa=df.loc[(df['Continent']=='South America') & (df['Year']==2000),'Internet Users(%)'].mean()
sum_IU_00_af=df.loc[(df['Continent']=='Africa') & (df['Year']==2000),'Internet Users(%)'].mean()
sum_IU_00_oc=df.loc[(df['Continent']=='Oceania') & (df['Year']==2000),'Internet Users(%)'].mean()

user_pctg_00=[sum_IU_00_as,sum_IU_00_eu,sum_IU_00_na,sum_IU_00_sa,sum_IU_00_af,sum_IU_00_oc]

sum_IU_20_as=df.loc[(df['Continent']=='Asia') & (df['Year']==2020),'Internet Users(%)'].mean()
sum_IU_20_eu=df.loc[(df['Continent']=='Europe') & (df['Year']==2020),'Internet Users(%)'].mean()
sum_IU_20_na=df.loc[(df['Continent']=='North America') & (df['Year']==2020),'Internet Users(%)'].mean()
sum_IU_20_sa=df.loc[(df['Continent']=='South America') & (df['Year']==2020),'Internet Users(%)'].mean()
sum_IU_20_af=df.loc[(df['Continent']=='Africa') & (df['Year']==2020),'Internet Users(%)'].mean()
sum_IU_20_oc=df.loc[(df['Continent']=='Oceania') & (df['Year']==2020),'Internet Users(%)'].mean()

user_pctg_20=[sum_IU_20_as,sum_IU_20_eu,sum_IU_20_na,sum_IU_20_sa,sum_IU_20_af,sum_IU_20_oc]

continents=['Asia','Europe','North America','South America','Africa','Oceania']

fig,ax=plt.subplots(1,2,figsize=(14,6))
ax[0].bar(continents,user_pctg_00,color='skyblue')
ax[0].set_xticks(range(len(continents)))
ax[0].set_xticklabels(continents,rotation=45)
ax[0].set_ylabel("Internet Users(%)")
ax[0].set_xlabel("Continent")
ax[0].set_title("Average % internet users in 2000 Continent wise")
ax[1].bar(continents,user_pctg_20,color='skyblue')
ax[1].set_xticks(range(len(continents)))
ax[1].set_xticklabels(continents,rotation=45)
ax[1].set_ylabel("Internet Users(%)")
ax[1].set_xlabel("Continent")
ax[1].set_title("Average % internet users in 2020 Continent wise")
plt.show()

sum_u_00_as=df.loc[(df['Continent']=='Asia') & (df['Year']==2000),'No. of Internet Users'].sum()
sum_u_00_eu=df.loc[(df['Continent']=='Europe') & (df['Year']==2000),'No. of Internet Users'].sum()
sum_u_00_na=df.loc[(df['Continent']=='North America') & (df['Year']==2000),'No. of Internet Users'].sum()
sum_u_00_sa=df.loc[(df['Continent']=='South America') & (df['Year']==2000),'No. of Internet Users'].sum()
sum_u_00_af=df.loc[(df['Continent']=='Africa') & (df['Year']==2000),'No. of Internet Users'].sum()
sum_u_00_oc=df.loc[(df['Continent']=='Oceania') & (df['Year']==2000),'No. of Internet Users'].sum()

user_count_00=[sum_u_00_as,sum_u_00_eu,sum_u_00_na,sum_u_00_sa,sum_u_00_af,sum_u_00_oc]

sum_u_20_as=df.loc[(df['Continent']=='Asia') & (df['Year']==2020),'No. of Internet Users'].sum()
sum_u_20_eu=df.loc[(df['Continent']=='Europe') & (df['Year']==2020),'No. of Internet Users'].sum()
sum_u_20_na=df.loc[(df['Continent']=='North America') & (df['Year']==2020),'No. of Internet Users'].sum()
sum_u_20_sa=df.loc[(df['Continent']=='South America') & (df['Year']==2020),'No. of Internet Users'].sum()
sum_u_20_af=df.loc[(df['Continent']=='Africa')& (df['Year']==2020),'No. of Internet Users'].sum()
sum_u_20_oc=df.loc[(df['Continent']=='Oceania') & (df['Year']==2020),'No. of Internet Users'].sum()

user_count_20=[sum_u_20_as,sum_u_20_eu,sum_u_20_na,sum_u_20_sa,sum_u_20_af,sum_u_20_oc]

continents=['Asia','Europe','North America','South America','Africa','Oceania']

fig,ax=plt.subplots(1,2,figsize=(14,6))
ax[0].bar(continents,user_count_00,color='skyblue')
ax[0].set_xticks(range(len(continents)))
ax[0].set_xticklabels(continents,rotation=45)
ax[0].set_ylabel("No. of Internet Users")
ax[0].set_xlabel("Continent")
ax[0].set_title("Total No. of Internet Users in 2000 Continent wise")
ax[1].bar(continents,user_count_20,color='skyblue')
ax[1].set_xticks(range(len(continents)))
ax[1].set_xticklabels(continents,rotation=45)
ax[1].set_ylabel("No. of Internet Users")
ax[1].set_xlabel("Continent")
ax[1].set_title("Total No. of Internet Users in 2020 Continent wise")
plt.show()


max_no_as_2000 = df[(df['Continent']=='Asia')&((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2000)].nlargest(10, 'No. of Internet Users')
max_no_eu_2000 = df[(df['Continent']=='Europe')&((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2000)].nlargest(10, 'No. of Internet Users')
max_no_na_2000 = df[(df['Continent']=='North America')&((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2000)].nlargest(10, 'No. of Internet Users')
max_no_sa_2000 = df[(df['Continent']=='South America')&((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2000)].nlargest(10, 'No. of Internet Users')
max_no_af_2000 = df[(df['Continent']=='Africa')&((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2000)].nlargest(10, 'No. of Internet Users')
max_no_oc_2000 = df[(df['Continent']=='Oceania')&((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2000)].nlargest(10, 'No. of Internet Users')

fig,ax=plt.subplots(3,2,figsize=(16,26))
plt.subplots_adjust(hspace=0.6)
ax[0,0].bar(max_no_as_2000['Entity'], max_no_as_2000['No. of Internet Users'], color='skyblue')
ax[0,0].set_xticks(range(len(max_no_as_2000['Entity'])))
ax[0,0].set_xticklabels(max_no_as_2000['Entity'],rotation=60)
ax[0,0].set_ylabel("No. of Internet Users")
ax[0,0].set_xlabel("Entity")
ax[0,0].set_title("Top 10 Countries in Asia with Most Internet Users in 2000 ")

ax[0,1].bar(max_no_eu_2000['Entity'], max_no_eu_2000['No. of Internet Users'], color='skyblue')
ax[0,1].set_xticks(range(len(max_no_eu_2000['Entity'])))
ax[0,1].set_xticklabels(max_no_eu_2000['Entity'],rotation=60)
ax[0,1].set_ylabel("No. of Internet Users")
ax[0,1].set_xlabel("Entity")
ax[0,1].set_title("Top 10 Countries in Europe with Most Internet Users in 2000 ")

ax[1,0].bar(max_no_na_2000['Entity'], max_no_na_2000['No. of Internet Users'], color='skyblue')
ax[1,0].set_xticks(range(len(max_no_na_2000['Entity'])))
ax[1,0].set_xticklabels(max_no_na_2000['Entity'],rotation=60)
ax[1,0].set_ylabel("No. of Internet Users")
ax[1,0].set_xlabel("Entity")
ax[1,0].set_title("Top 10 Countries in North America with Most Internet Users in 2000 ")

ax[1,1].bar(max_no_sa_2000['Entity'], max_no_sa_2000['No. of Internet Users'], color='skyblue')
ax[1,1].set_xticks(range(len(max_no_sa_2000['Entity'])))
ax[1,1].set_xticklabels(max_no_sa_2000['Entity'],rotation=60)
ax[1,1].set_ylabel("No. of Internet Users")
ax[1,1].set_xlabel("Entity")
ax[1,1].set_title("Top 10 Countries in South America with Most Internet Users in 2000 ")

ax[2,0].bar(max_no_af_2000['Entity'], max_no_af_2000['No. of Internet Users'], color='skyblue')
ax[2,0].set_xticks(range(len(max_no_af_2000['Entity'])))
ax[2,0].set_xticklabels(max_no_af_2000['Entity'],rotation=60)
ax[2,0].set_ylabel("No. of Internet Users")
ax[2,0].set_xlabel("Entity")
ax[2,0].set_title("Top 10 Countries in Africa with Most Internet Users in 2000 ")

ax[2,1].bar(max_no_oc_2000['Entity'], max_no_oc_2000['No. of Internet Users'], color='skyblue')
ax[2,1].set_xticks(range(len(max_no_oc_2000['Entity'])))
ax[2,1].set_xticklabels(max_no_oc_2000['Entity'],rotation=60)
ax[2,1].set_ylabel("No. of Internet Users")
ax[2,1].set_xlabel("Entity")
ax[2,1].set_title("Top 10 Countries in Oceania with Most Internet Users in 2000 ")
plt.show()


max_no_as_2020 = df[(df['Continent']=='Asia')&((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2020)].nlargest(10, 'No. of Internet Users')
max_no_eu_2020 = df[(df['Continent']=='Europe')&((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2020)].nlargest(10, 'No. of Internet Users')
max_no_na_2020 = df[(df['Continent']=='North America')&((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2020)].nlargest(10, 'No. of Internet Users')
max_no_sa_2020 = df[(df['Continent']=='South America')&((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2020)].nlargest(10, 'No. of Internet Users')
max_no_af_2020 = df[(df['Continent']=='Africa')&((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2020)].nlargest(10, 'No. of Internet Users')
max_no_oc_2020 = df[(df['Continent']=='Oceania')&((df['Entity'] != 'World')&(df['Entity'] != 'North America'))&(df['Year']==2020)].nlargest(10, 'No. of Internet Users')

fig,ax=plt.subplots(3,2,figsize=(16,26))
plt.subplots_adjust(hspace=0.6)
ax[0,0].bar(max_no_as_2020['Entity'], max_no_as_2020['No. of Internet Users'], color='skyblue')
ax[0,0].set_xticks(range(len(max_no_as_2020['Entity'])))
ax[0,0].set_xticklabels(max_no_as_2020['Entity'],rotation=60)
ax[0,0].set_ylabel("No. of Internet Users")
ax[0,0].set_xlabel("Entity")
ax[0,0].set_title("Top 10 Countries in Asia with Most Internet Users in 2020 ")

ax[0,1].bar(max_no_eu_2020['Entity'], max_no_eu_2020['No. of Internet Users'], color='skyblue')
ax[0,1].set_xticks(range(len(max_no_eu_2020['Entity'])))
ax[0,1].set_xticklabels(max_no_eu_2020['Entity'],rotation=60)
ax[0,1].set_ylabel("No. of Internet Users")
ax[0,1].set_xlabel("Entity")
ax[0,1].set_title("Top 10 Countries in Europe with Most Internet Users in 2020 ")

ax[1,0].bar(max_no_na_2020['Entity'], max_no_na_2020['No. of Internet Users'], color='skyblue')
ax[1,0].set_xticks(range(len(max_no_na_2020['Entity'])))
ax[1,0].set_xticklabels(max_no_na_2020['Entity'],rotation=60)
ax[1,0].set_ylabel("No. of Internet Users")
ax[1,0].set_xlabel("Entity")
ax[1,0].set_title("Top 10 Countries in North America with Most Internet Users in 2020 ")

ax[1,1].bar(max_no_sa_2020['Entity'], max_no_sa_2020['No. of Internet Users'], color='skyblue')
ax[1,1].set_xticks(range(len(max_no_sa_2020['Entity'])))
ax[1,1].set_xticklabels(max_no_sa_2020['Entity'],rotation=60)
ax[1,1].set_ylabel("No. of Internet Users")
ax[1,1].set_xlabel("Entity")
ax[1,1].set_title("Top 10 Countries in South America with Most Internet Users in 2020 ")

ax[2,0].bar(max_no_af_2020['Entity'], max_no_af_2020['No. of Internet Users'], color='skyblue')
ax[2,0].set_xticks(range(len(max_no_af_2020['Entity'])))
ax[2,0].set_xticklabels(max_no_af_2020['Entity'],rotation=60)
ax[2,0].set_ylabel("No. of Internet Users")
ax[2,0].set_xlabel("Entity")
ax[2,0].set_title("Top 10 Countries in Africa with Most Internet Users in 2020 ")

ax[2,1].bar(max_no_oc_2020['Entity'], max_no_oc_2020['No. of Internet Users'], color='skyblue')
ax[2,1].set_xticks(range(len(max_no_oc_2020['Entity'])))
ax[2,1].set_xticklabels(max_no_oc_2020['Entity'],rotation=60)
ax[2,1].set_ylabel("No. of Internet Users")
ax[2,1].set_xlabel("Entity")
ax[2,1].set_title("Top 10 Countries in Oceania with Most Internet Users in 2020 ")
plt.show()

plt.figure()
country_name=input("enter country name in form of Abc:")
co_df=df[df['Entity']==country_name]
plt.plot(co_df['Year'],co_df['Cellular Subscription'])
plt.plot(co_df['Year'],co_df['Internet Users(%)'])
plt.plot(co_df['Year'],co_df['No. of Internet Users']/10000000)
plt.plot(co_df['Year'],co_df['Broadband Subscription'])
plt.legend(['Cellular Subscription','Internet Users(%)','No. of Internet Users in 10 million','Broadband Subscription'])
plt.xlabel('Year')
plt.ylabel('Values')
plt.title(country_name,fontsize="40")
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Final.csv
#       Unnamed: 0       Entity Code  Year  Cellular Subscription  \
# 0              0  Afghanistan  AFG  1980               0.000000
# 1              1  Afghanistan  AFG  1981               0.000000
# 2              2  Afghanistan  AFG  1982               0.000000
# 3              3  Afghanistan  AFG  1983               0.000000
# 4              4  Afghanistan  AFG  1984               0.000000
# ...          ...          ...  ...   ...                    ...
# 8862        8862     Zimbabwe  ZWE  2016              91.793457
# 8863        8863     Zimbabwe  ZWE  2017              98.985077
# 8864        8864     Zimbabwe  ZWE  2018              89.404869
# 8865        8865     Zimbabwe  ZWE  2019              90.102287
# 8866        8866     Zimbabwe  ZWE  2020              88.755806
#
# ...
